# %% [markdown]
# ##### Importing required packages

# %%
import pathlib
import os

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from datetime import date

from sklearn.preprocessing import MinMaxScaler

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC

from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve

import pickle

# %% [markdown]
# ##### Setting notebook and plotting options

# %%
pd.set_option("display.max_columns", None)

# %%
## Setting plotting styles and context
sns.set(font_scale = 1)
sns.set(rc={"figure.dpi":100})

sns.set_style('whitegrid')
sns.set_context('notebook')

sns.set_palette("deep")

# %%
repo_path = pathlib.Path().resolve()

os.chdir(str(repo_path))

# %% [markdown]
# ##### Reading in the data for modeling

# %%
modeling_data = pd.read_csv("Data/Kmeans_Labeled_Customer_Data.csv")

# %%
modeling_data.shape
# Out:
# (2206, 30)

# %% [markdown]
# # Classification

# %% [markdown]
# ### Checking correlations

# %%
def _color_red_or_green(val):
    color = 'red' if val < -0.6 else 'light'
    color = 'green' if val > 0.6 else color
    return 'background-color: %s' % color

modeling_data.corr().style.applymap(_color_red_or_green)
# Out:
# <style type="text/css">
# #T_fc5af_row0_col0, #T_fc5af_row1_col1, #T_fc5af_row2_col2, #T_fc5af_row2_col7, #T_fc5af_row2_col9, #T_fc5af_row2_col20, #T_fc5af_row2_col21, #T_fc5af_row3_col3, #T_fc5af_row3_col4, #T_fc5af_row3_col5, #T_fc5af_row3_col25, #T_fc5af_row4_col3, #T_fc5af_row4_col4, #T_fc5af_row5_col3, #T_fc5af_row5_col5, #T_fc5af_row6_col6, #T_fc5af_row7_col2, #T_fc5af_row7_col7, #T_fc5af_row7_col20, #T_fc5af_row7_col21, #T_fc5af_row8_col8, #T_fc5af_row9_col2, #T_fc5af_row9_col9, #T_fc5af_row9_col20, #T_fc5af_row10_col10, #T_fc5af_row11_col11, #T_fc5af_row12_col12, #T_fc5af_row13_col13, #T_fc5af_row13_col26, #T_fc5af_row14_col14, #T_fc5af_row15_col15, #T_fc5af_row16_col16, #T_fc5af_row16_col26, #T_fc5af_row17_col17, #T_fc5af_row17_col26, #T_fc5af_row18_col18, #T_fc5af_row19_col19, #T_fc5af_row20_col2, #T_fc5af_row20_col7, #T_fc5af_row20_col9, #T_fc5af_row20_col20, #T_fc5af_row21_col2, #T_fc5af_row21_col7, #T_fc5af_row21_col21, #T_fc5af_row22_col22, #T_fc5af_row23_col23, #T_fc5af_row24_col24, #T_fc5af_row25_col3, #T_fc5af_row25_col25, #T_fc5af_row26_col13, #T_fc5af_row26_col16, #T_fc5af_row26_col17, #T_fc5af_row26_col26, #T_fc5af_row27_col27, #T_fc5af_row28_col28, #T_fc5af_row29_col29 {
#   background-color: green;
# }
# #T_fc5af_row0_col1, #T_fc5af_row0_col2, #T_fc5af_row0_col3, #T_fc5af_row0_col4, #T_fc5af_row0_col5, #T_fc5af_row0_col6, #T_fc5af_row0_col7, #T_fc5af_row0_col8, #T_fc5af_row0_col9, #T_fc5af_row0_col10, #T_fc5af_row0_col11, #T_fc5af_row0_col12, #T_fc5af_row0_col13, #T_fc5af_row0_col14, #T_fc5af_row0_col15, #T_fc5af_row0_col16, #T_fc5af_row0_col17, #T_fc5af_row0_col18, #T_fc5af_row0_col19, #T_fc5af_row0_col20, #T_fc5af_row0_col21, #T_fc5af_row0_col22, #T_fc5af_row0_col23, #T_fc5af_row0_col24, #T_fc5af_row0_col25, #T_fc5af_row0_col26, #T_fc5af_row0_col27, #T_fc5af_row0_col28, #T_fc5af_row0_col29, #T_fc5af_row1_col0, #T_fc5af_row1_col2, #T_fc5af_row1_col3, #T_fc5af_row1_col4, #T_fc5af_row1_col5, #T_fc5af_row1_col6, #T_fc5af_row1_col7, #T_fc5af_row1_col8, #T_fc5af_row1_col9, #T_fc5af_row1_col10, #T_fc5af_row1_col11, #T_fc5af_row1_col12, #T_fc5af_row1_col13, #T_fc5af_row1_col14, #T_fc5af_row1_col15, #T_fc5af_row1_col16, #T_fc5af_row1_col17, #T_fc5af_row1_col18, #T_fc5af_row1_col19, #T_fc5af_row1_col20, #T_fc5af_row1_col21, #T_fc5af_row1_col22, #T_fc5af_row1_col23, #T_fc5af_row1_col24, #T_fc5af_row1_col25, #T_fc5af_row1_col26, #T_fc5af_row1_col27, #T_fc5af_row1_col28, #T_fc5af_row2_col0, #T_fc5af_row2_col1, #T_fc5af_row2_col3, #T_fc5af_row2_col4, #T_fc5af_row2_col5, #T_fc5af_row2_col6, #T_fc5af_row2_col8, #T_fc5af_row2_col10, #T_fc5af_row2_col11, #T_fc5af_row2_col12, #T_fc5af_row2_col13, #T_fc5af_row2_col14, #T_fc5af_row2_col15, #T_fc5af_row2_col16, #T_fc5af_row2_col17, #T_fc5af_row2_col18, #T_fc5af_row2_col19, #T_fc5af_row2_col22, #T_fc5af_row2_col24, #T_fc5af_row2_col25, #T_fc5af_row2_col26, #T_fc5af_row2_col27, #T_fc5af_row2_col28, #T_fc5af_row2_col29, #T_fc5af_row3_col0, #T_fc5af_row3_col1, #T_fc5af_row3_col2, #T_fc5af_row3_col6, #T_fc5af_row3_col7, #T_fc5af_row3_col8, #T_fc5af_row3_col9, #T_fc5af_row3_col10, #T_fc5af_row3_col11, #T_fc5af_row3_col12, #T_fc5af_row3_col13, #T_fc5af_row3_col14, #T_fc5af_row3_col15, #T_fc5af_row3_col16, #T_fc5af_row3_col17, #T_fc5af_row3_col18, #T_fc5af_row3_col19, #T_fc5af_row3_col20, #T_fc5af_row3_col21, #T_fc5af_row3_col22, #T_fc5af_row3_col23, #T_fc5af_row3_col24, #T_fc5af_row3_col26, #T_fc5af_row3_col27, #T_fc5af_row3_col28, #T_fc5af_row3_col29, #T_fc5af_row4_col0, #T_fc5af_row4_col1, #T_fc5af_row4_col2, #T_fc5af_row4_col5, #T_fc5af_row4_col6, #T_fc5af_row4_col7, #T_fc5af_row4_col8, #T_fc5af_row4_col9, #T_fc5af_row4_col10, #T_fc5af_row4_col11, #T_fc5af_row4_col12, #T_fc5af_row4_col13, #T_fc5af_row4_col14, #T_fc5af_row4_col15, #T_fc5af_row4_col16, #T_fc5af_row4_col17, #T_fc5af_row4_col18, #T_fc5af_row4_col19, #T_fc5af_row4_col20, #T_fc5af_row4_col21, #T_fc5af_row4_col22, #T_fc5af_row4_col23, #T_fc5af_row4_col24, #T_fc5af_row4_col25, #T_fc5af_row4_col26, #T_fc5af_row4_col27, #T_fc5af_row4_col28, #T_fc5af_row4_col29, #T_fc5af_row5_col0, #T_fc5af_row5_col1, #T_fc5af_row5_col2, #T_fc5af_row5_col4, #T_fc5af_row5_col6, #T_fc5af_row5_col7, #T_fc5af_row5_col8, #T_fc5af_row5_col9, #T_fc5af_row5_col10, #T_fc5af_row5_col11, #T_fc5af_row5_col12, #T_fc5af_row5_col13, #T_fc5af_row5_col14, #T_fc5af_row5_col15, #T_fc5af_row5_col16, #T_fc5af_row5_col17, #T_fc5af_row5_col18, #T_fc5af_row5_col19, #T_fc5af_row5_col20, #T_fc5af_row5_col21, #T_fc5af_row5_col22, #T_fc5af_row5_col23, #T_fc5af_row5_col24, #T_fc5af_row5_col25, #T_fc5af_row5_col26, #T_fc5af_row5_col27, #T_fc5af_row5_col28, #T_fc5af_row5_col29, #T_fc5af_row6_col0, #T_fc5af_row6_col1, #T_fc5af_row6_col2, #T_fc5af_row6_col3, #T_fc5af_row6_col4, #T_fc5af_row6_col5, #T_fc5af_row6_col7, #T_fc5af_row6_col8, #T_fc5af_row6_col9, #T_fc5af_row6_col10, #T_fc5af_row6_col11, #T_fc5af_row6_col12, #T_fc5af_row6_col13, #T_fc5af_row6_col14, #T_fc5af_row6_col15, #T_fc5af_row6_col16, #T_fc5af_row6_col17, #T_fc5af_row6_col18, #T_fc5af_row6_col19, #T_fc5af_row6_col20, #T_fc5af_row6_col21, #T_fc5af_row6_col22, #T_fc5af_row6_col23, #T_fc5af_row6_col24, #T_fc5af_row6_col25, #T_fc5af_row6_col26, #T_fc5af_row6_col27, #T_fc5af_row6_col28, #T_fc5af_row6_col29, #T_fc5af_row7_col0, #T_fc ...

# %% [markdown]
# ##### Dropping some of the correlated attributes and other unwanted attributes such as clustering labels etc.

# %%
# 'Kidhome', 'Teenhome', 
# 'AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4','AcceptedCmp5'

# c_to_drop = ['ID','CampAccepted', 'Family_Size', 'Children']
c_to_drop = ['Kidhome', 'Teenhome', 'Family_Size', 'AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4','AcceptedCmp5','labels']
c_to_drop.extend(['NumCatalogPurchases','NumStorePurchases','Meat','NumWebVisitsMonth'])
c_temp = modeling_data.drop(c_to_drop, axis = 1)

# %%
c_temp.shape
# Out:
# (2206, 17)

# %%
c_temp.columns
# Out:
# Index(['ID', 'Relationship_Status', 'Income', 'Children', 'Enroll_Age',
#        'Wines', 'Fruits', 'Fish', 'Sweets', 'Gold', 'Response',
#        'NumWebPurchases', 'NumDealsPurchases', 'Age', 'CampAccepted',
#        'Education', 'spend_per_unit_income'],
#       dtype='object')

# %% [markdown]
# ##### Splitting response and features from the data

# %%
c_X = c_temp.drop('Response', axis = 1)
c_y = c_temp['Response']

# %% [markdown]
# ### Train and test split of data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test  = train_test_split(c_X.values, c_y, test_size = 0.2, stratify = c_y, random_state=1995)

# %%
train_ids = X_train[:,0]
test_ids = X_test[:,0]

X_train =  X_train[:,1:]
X_test =  X_test[:,1:]

# %% [markdown]
# ##### Checking if the train and test ids conform to the original dataset

# %%
print(sum(c_X.ID))
print(sum(train_ids) + sum(test_ids))
# Out:
# 12317053
# 12317053.0

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1764, 15)
# (442, 15)
# (1764,)
# (442,)

# %%
print("Training Target Class Distribution:")
print(pd.Series(y_train).value_counts().sort_values().to_string(),"\n\n")

print("Test Target Class Distribution:")
print(pd.Series(y_test).value_counts().sort_values().to_string())
# Out:
# Training Target Class Distribution:
# 1     265
# 0    1499
#
#
# Test Target Class Distribution:
# 1     66
# 0    376

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1764, 15)
# (442, 15)
# (1764,)
# (442,)

# %% [markdown]
# ### Setting up the Grid Search for best model

# %% [markdown]
# ##### Initializing the estimator

# %%
# Setting up the pipleline steps and initializing the grid search object
c_scaler = MinMaxScaler(feature_range=(-1,1))

# Initializing the estimator
# clf = LogisticRegression()
# clf = RandomForestClassifier(random_state=21)
clf = SVC(random_state=21)

steps = [('Scale', c_scaler),('Clf', clf)]
pipeline = Pipeline(steps)

# %% [markdown]
# ##### Building the parameters dictionary for grid search

# %%
# Logistic Parameters for GridSearchCV

# param_grid = { 
#     'Clf__C': np.arange(0.1,1,0.1),
#     'Clf__penalty':['l2','elasticnet']
# }

# # SVM Parameters for GridSearchCV
param_grid = { 
    'Clf__C': np.arange(0.1,2,0.05),
    'Clf__kernel':['rbf', 'linear']

}

# param_grid = { 
#     'Clf__kernel': ['rbf'],
# #     'Clf__max_iter':[1000,2000,3000],
#     'Clf__gamma' : np.arange(0.1,1,0.1)    
# }


# Random Forest Parameters for GridSearchCV

# param_grid = { 
#     'Clf__n_estimators': [100, 200, 300],
#     'Clf__max_features': ['sqrt', 'log2', 'auto'],
#     'Clf__max_depth' : [None,2,4,6],
#     'Clf__criterion' :['gini','logloss'],
#     'Clf__min_samples_split':[2,3,4]
# }

# %% [markdown]
# ##### Initializing the Grid Search Object

# %%
cv = GridSearchCV(pipeline, param_grid=param_grid, cv=4, scoring = 'f1')

# %% [markdown]
# ##### Fitting the GridSearchCV object and predicting the class labels for both train and test set.

# %%
cv.fit(X_train, y_train)
y_tpred = cv.predict(X_train)
y_pred = cv.predict(X_test)

# %%
print(cv.best_estimator_.get_params)
# Out:
# <bound method Pipeline.get_params of Pipeline(steps=[('Scale', MinMaxScaler(feature_range=(-1, 1))),
#                 ('Clf', SVC(C=1.8500000000000008, random_state=21))])>

# %% [markdown]
# ##### Evaluation metrics for the best estimator and calculating test metrics

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print(cv.best_params_)

print("Training F1 Score: ", round(cv.score(X_train, y_train),2))
print("Testing F1 Score: ", round(cv.score(X_test, y_test),2))

print("\n")

print("Training Accuracy Score: ", round(cv.best_estimator_.score(X_train, y_train)*100,2))
print("Testing Accuracy Score: ", round(cv.best_estimator_.score(X_test, y_test)*100,2))

print("\n")

print("Training Data Confusion Matrix")
print(confusion_matrix(y_train, y_tpred))

print("\n")

print("Testing Data Confusion Matrix")
print(confusion_matrix(y_test, y_pred))

print("\n")

print("Testing Data Classification Report")
print(classification_report(y_test, y_pred))
# Out:
# {'Clf__C': 1.8500000000000008, 'Clf__kernel': 'rbf'}
# Training F1 Score:  0.46
# Testing F1 Score:  0.31
#
#
# Training Accuracy Score:  89.0
# Testing Accuracy Score:  86.65
#
#
# Training Data Confusion Matrix
# [[1489   10]
#  [ 184   81]]
#
#
# Testing Data Confusion Matrix
# [[370   6]
#  [ 53  13]]
#
#
# Testing Data Classification Report
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.93       376
#            1       0.68      0.20      0.31        66
#
#     accuracy                           0.87       442
#    macro avg       0.78      0.59      0.62       442
# weighted avg       0.85      0.87      0.83       442

# %% [markdown]
# ##### Concatenating all the data (features, response, predictions and IDs) and creating flags to identify the observation split (train or test)

# %%
temp_1 = pd.concat([
    pd.DataFrame(data = X_train, columns = c_X.columns[1:]).reset_index(drop = True),
    pd.DataFrame(data = y_train, columns = ['Response']).reset_index(drop = True),
    pd.DataFrame(data = y_tpred, columns = ['Predictions']).reset_index(drop = True),
    pd.DataFrame(data = train_ids, columns = ['ID']).reset_index(drop = True)]
    ,axis = 1)

temp_1["split"] = 'train'

temp_2 = pd.concat([
    pd.DataFrame(data = X_test, columns = c_X.columns[1:]).reset_index(drop = True),
    pd.DataFrame(data = y_test, columns = ['Response']).reset_index(drop = True),
    pd.DataFrame(data = y_pred, columns = ['Predictions']).reset_index(drop = True),
    pd.DataFrame(data = test_ids, columns = ['ID']).reset_index(drop = True)]
    ,axis = 1)   

temp_2["split"] = 'test'

# %%
campaign_data_w_predictions = pd.concat([temp_1,temp_2])

# %% [markdown]
# ##### ID sum check to make sure of concatenated data sanity

# %%
print(campaign_data_w_predictions.ID.sum())
print(c_X.ID.sum())
# Out:
# 12317053.0
# 12317053

# %% [markdown]
# ##### Saving the modeling results (predictions to csv and the cv estimator as a pickled file)

# %%
campaign_data_w_predictions.to_csv("campaign_data_w_predictions.csv")

# %%
filename = 'Model/svc_cv_obj.sav'
pickle.dump(cv, open(filename, 'wb'))

# filename = 'Model/svc_cv_obj.sav'
# pickle.load(open(filename, 'rb'))
